# %%
# Import libraries

# To write a Python 2/3 compatible codebase, the first step is to add this line to the top of each module
from __future__ import division, print_function, unicode_literals

import pandas as pd
import numpy as np
import scipy as sp
from datetime import datetime

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

#import pandas_profiling
import os, sys

import datetime

import numpy

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler # Standardize features by removing the mean and scaling to unit variance
from sklearn.preprocessing import MinMaxScaler

import gc

import math

import ftfy

gc.collect()
# Out:
# 0

# %% [markdown]
# # Joined

# %%
# Set of columns and rows to display

pd.set_option('max_columns', None)
pd.set_option('max_rows', 500)

# %%
# Import data

data = pd.read_excel('In Possession Stats.xlsx')

data_out = pd.read_excel('Out of Possession Stats.xlsx')


data.head()
# Out:
#    Rank                   playerId  playerImageId         Player  \
# 0     1  bdwbbro06256s61ed42kejvmd       102680.0           Ilie
# 1     2  eds7hz8z52qf06c3oug7nivv9        49720.0  H. Medunjanin
# 2     3  16dmszlgoxqwzncidglrv9j9x       111681.0    R. Espinoza
# 3     4  35fvjkn05x6cr2kx3yiif1jop       235848.0          Artur
# 4     5  d38mrccgoud3qomh3supk202d       142574.0       D. Nagbe
#
#                 playerFullName                   pos  teamImageId  \
# 0        Ilie SÃ¡nchez FarrÃ©s    Central Midfielder          421
# 1             Haris Medunjanin  Defensive Midfielder         5513
# 2     RÃ³ger Espinoza RamÃ­rez    Central Midfielder          421
# 3    Jose Artur de Lima Junior  Defensive Midfielder          454
# 4  Darlington Joephillip Nagbe    Central Midfielder        11091
#
#              teamName   teamShortName teamAbbrevName  \
# 0         Sporting KC     Sporting KC            SKC
# 1  Philadelphia Union    Philadelphia            PHI
# ...

# %%
# Joining Files

joined = data.merge(data_out, how='left', left_on=['playerId','Season'], right_on=['playerId','Season'])

# %%
# Cleaning data

joined['Ps%CmpD3'] = joined['Ps%CmpD3'].replace("-", 0)
joined['Ps%CmpD3'] = joined['Ps%CmpD3'].astype("float")

joined['TakeOn%'] = joined['TakeOn%'].replace("-", 0)
joined['TakeOn%'] = joined['TakeOn%'].astype("float")

joined['%ShotInBox'] = joined['%ShotInBox'].replace("-", 0)
joined['%ShotInBox'] = joined['%ShotInBox'].astype("float")

joined['%ShotHead'] = joined['%ShotHead'].replace("-", 0)
joined['%ShotHead'] = joined['%ShotHead'].astype("float")

joined['Duel%D3'] = joined['Duel%D3'].replace("-", 0)
joined['Duel%D3'] = joined['Duel%D3'].astype("float")

joined['Duel%A3'] = joined['Duel%A3'].replace("-", 0)
joined['Duel%A3'] = joined['Duel%A3'].astype("float")

joined['Aerial%'] = joined['Aerial%'].replace("-", 0)
joined['Aerial%'] = joined['Aerial%'].astype("float")

joined['Arl%DH'] = joined['Arl%DH'].replace("-", 0)
joined['Arl%DH'] = joined['Arl%DH'].astype("float")

joined['TcklMade%'] = joined['TcklMade%'].replace("-", 0)
joined['TcklMade%'] = joined['TcklMade%'].astype("float")

joined['Arl%AH'] = joined['Arl%AH'].replace("-", 0)
joined['Arl%AH'] = joined['Arl%AH'].astype("float")

# %% [markdown]
# # 2020 Season

# %%
# Filtered by 2020 season

joined_2020 = joined[joined.Season == 'MLS 2020 (USA)']

# %%
# Dropped ID and categorical columns 

joined_2020.drop(['playerImageId_x', 'null_x', "Rank_y", "playerImageId_y", "null_y", 'Rank_x', 'playerId', 'Player_x', 'pos_x', 'teamImageId_x', 'teamName_x', 'teamShortName_x', 'teamAbbrevName_x', 'teamId_x','optaPersonId_x','leagueId_x','leagueName_x','Position_x','Team_x','seasonId_x','scatterId_x','scatterExtra_x' , 'Player_y', 'playerFullName_y', 'pos_y', 'teamImageId_y', 'teamName_y','teamShortName_y', 'teamAbbrevName_y', 'teamId_y', 'optaPersonId_y', 'firstName_y', 'lastName_y', 'optaTeamId_y', 'leagueId_y','Position_y', 'Team_y', 'GM_y', 'Min_y', 'Age_y', 'seasonId_y', 'scatterId_y', 'scatterExtra_y', 'Season', 'firstName_x', 'lastName_x', 'optaTeamId_x', 'leagueName_y'], axis=1, inplace=True)
# Out:
# C:\Users\cassi\anaconda3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# Reset index

joined_2020.reset_index(inplace=True)

# %% [markdown]
# #### Fixing players names

# %%
players = joined_2020[['playerFullName_x']]

# %%
names = []

for i in players['playerFullName_x']:
    results = ftfy.fix_text(i)
    names.append(results)

# %%
names = pd.DataFrame(names)
names.columns = ['playerFullName_x']

# %%
players = names.copy()

# %%
joined_2020.drop(['index', 'playerFullName_x'], axis=1, inplace=True)

# %%
joined_2020.head()
# Out:
#    GM_x  Min_x  Age_x  MinIncET  Touches  TchsA3  TouchOpBox  %TouchesWide  \
# 0    27   2340     25      2528     1784     568          84         0.770
# 1    26   2310     29      2511     1829     372          36         0.537
# 2    27   2309     24      2486     1804     265          32         0.622
# 3    25   2279     34      2478     1791     182          11         0.578
# 4    25   2232     31      2400     2381    1029          67         0.820
#
#    RecDist  PsRecD3  PsRecM3  PsRecA3  PsRec  PsAtt  Pass%  PsDist  \
# 0     15.1      180      563      379   1122   1298  0.816    17.6
# 1     14.0      236      624      235   1095   1433  0.838    18.5
# 2     13.1      231      796      158   1185   1476  0.882    18.5
# 3     13.7      277      695       97   1069   1427  0.891    18.3
# 4     13.4       85      865      599   1549   1684  0.809    16.9
#
#    ShrtPassAtt  %ShortPassCmp  LongPassAtt  %LgPassCmp  %PsInOppHalf  \
# ...

# %%
players
# Out:
#                               playerFullName_x
# 0                              Cristian Roldan
# 1                               Alexander Ring
# 2                    Jose Artur de Lima Junior
# 3                    Diego Ferney Chará Zamora
# 4              Marcelo Nicolás Lodeiro Benítez
# 5                       Jackson William Yueill
# 6                                   Ján Greguš
# 7                                Jordan Morris
# 8                                  Dax McCarty
# 9                           Álvaro Medrán Just
# 10                    Ocimar de Almeida Júnior
# 11                              Victor Wanyama
# 12                               Samuel Piette
# 13                            Haris Medunjanin
# 14                            Brenden Aaronson
# 15                        Judson Silva Tavares
# 16                      Keaton Alexander Parks
# 17                 Pedro Miguel Martins Santos
# 18                               Frankie Amaya
# ...

# %%
joined_2020.insert(0,'playerFullName_x', players)

# %%
joined_2020
# Out:
#                               playerFullName_x  GM_x  Min_x  Age_x  MinIncET  \
# 0                              Cristian Roldan    27   2340     25      2528
# 1                               Alexander Ring    26   2310     29      2511
# 2                    Jose Artur de Lima Junior    27   2309     24      2486
# 3                    Diego Ferney Chará Zamora    25   2279     34      2478
# 4              Marcelo Nicolás Lodeiro Benítez    25   2232     31      2400
# 5                       Jackson William Yueill    24   2161     23      2323
# 6                                   Ján Greguš    24   2139     30      2301
# 7                                Jordan Morris    26   2124     26      2241
# 8                                  Dax McCarty    24   2008     33      2129
# 9                           Álvaro Medrán Just    23   1996     26      2122
# 10                    Ocimar de Almeida Júnior    25   1901     32      2092
# ...

# %%
# Creating a list of unique players for the season

unique_2020 =joined_2020.playerFullName_x.unique()

# %%
dic_2020 = {}

# %%
# Created vector with features to be used in cosine similarity

for name in unique_2020:
    row = joined_2020[joined_2020["playerFullName_x"]==name].iloc[[0]]
    name = row.iloc[0]["playerFullName_x"]
    GM = row.iloc[0]["GM_x"]
    Min = row.iloc[0]["Min_x"]
    Age = row.iloc[0]["Age_x"]
    MinIncET= row.iloc[0]["MinIncET"]
    Touches= row.iloc[0]["Touches"]
    TchsA3= row.iloc[0]["TchsA3"]
    TouchOpBox= row.iloc[0]["TouchOpBox"]
    TouchesWide= row.iloc[0]["%TouchesWide"]
    RecDist= row.iloc[0]["RecDist"]
    PsRecD3= row.iloc[0]["PsRecD3"]
    PsRecM3= row.iloc[0]["PsRecM3"]
    PsRecA3= row.iloc[0]["PsRecA3"]
    PsRec= row.iloc[0]["PsRec"]
    PsAtt= row.iloc[0]["PsAtt"]
    Pass= row.iloc[0]["Pass%"]
    PsDist= row.iloc[0]["PsDist"]
    ShrtPassAtt= row.iloc[0]["ShrtPassAtt"]
    ShortPassCmp= row.iloc[0]["%ShortPassCmp"]
    LongPassAtt= row.iloc[0]["LongPassAtt"]
    LgPassCmp= row.iloc[0]["%LgPassCmp"]
    PsInOppHalf= row.iloc[0]["%PsInOppHalf"]
    PsInFinal3rd= row.iloc[0]["%PsInFinal3rd"]
    PsCmpD3= row.iloc[0]["Ps%CmpD3"]
    PsInA3rd= row.iloc[0]["Ps%InA3rd"]
    PsInBox= row.iloc[0]["PsInBox"]
    PsCmpInBox= row.iloc[0]["PsCmpInBox"]
    BackPass= row.iloc[0]["BackPass"]
    SquarePass= row.iloc[0]["SquarePass"]
    PsSoP=row.iloc[0]["PsSoP"]
    PsCmpSoP= row.iloc[0]["PsCmpSoP"]
    PassFwd= row.iloc[0]["%PassFwd"]
    FwdPsCmp= row.iloc[0]["FwdPsCmp%"]
    Carries=row.iloc[0]["Carries"]
    CarryDistAvg= row.iloc[0]["CarryDistAvg"]
    TakeOn= row.iloc[0]["TakeOn"]
    TakeOn= row.iloc[0]["TakeOn%"]
    FoulSuf = row.iloc[0]["FoulSuf"]
    FlSufD3 = row.iloc[0]["FlSufD3"]
    FlSufA3 = row.iloc[0]["FlSufA3"]
    CrossOpen = row.iloc[0]["CrossOpen"]
    TimeTckl= row.iloc[0]["TimeTckl"]
    PsLostD3= row.iloc[0]["PsLostD3"]
    PsLostM3= row.iloc[0]["PsLostM3"]
    PsLostA3= row.iloc[0]["PsLostA3"]
    SeqEndsInShot= row.iloc[0]["SeqEndsInShot"]
    SeqEndsInGoal= row.iloc[0]["SeqEndsInGoal"]
    Chance= row.iloc[0]["Chance"]
    KeyPass= row.iloc[0]["KeyPass"]
    Ast= row.iloc[0]["Ast"]
    Shot= row.iloc[0]["Shot"]
    SOG= row.iloc[0]["SOG"]
    ShotInBox= row.iloc[0]["%ShotInBox"]
    PossLost= row.iloc[0]["PossLost"]
    ShotHead= row.iloc[0]["%ShotHead"]
    xG= row.iloc[0]["xG"]
    Goal= row.iloc[0]["Goal"]
    
    
    
    Duels= row.iloc[0]["Duels"]
    DuelsD3= row.iloc[0]["DuelsD3"]
    DuelsM3= row.iloc[0]["DuelsM3"]
    DuelsA3= row.iloc[0]["DuelsA3"]
    Duel= row.iloc[0]["Duel%"]
    Duel_D3= row.iloc[0]["Duel%D3"]
    Duel_M3= row.iloc[0]["Duel%M3"]
    Duel_A3= row.iloc[0]["Duel%A3"]
    GrndDlWn= row.iloc[0]["GrndDlWn"]
    GrndDlLs= row.iloc[0]["GrndDlLs"]
    Aerials=row.iloc[0]["Aerials"]
    AerialWon= row.iloc[0]["AerialWon"]
    AerialLoss= row.iloc[0]["AerialLoss"]
    Aerial= row.iloc[0]["Aerial%"]
    Arl_DH=row.iloc[0]["Arl%DH"]
    Arl_AH= row.iloc[0]["Arl%AH"]
    Tckl= row.iloc[0]["Tckl"]
    TcklD3= row.iloc[0]["TcklD3"]
    TcklM3 = row.iloc[0]["TcklM3"]
    TcklA3 = row.iloc[0]["TcklA3"]
    IntA3 = row.iloc[0]["IntA3"]
    Int = row.iloc[0]["Int"]
    IntD3= row.iloc[0]["IntD3"]
    IntM3= row.iloc[0]["IntM3"]
    Clrnce= row.iloc[0]["Clrnce"]
    ClrncD3= row.iloc[0]["ClrncD3"]
    ClrncM3= row.iloc[0]["ClrncM3"]
    ClrncA3= row.iloc[0]["ClrncA3"]
    HeadClear= row.iloc[0]["HeadClear"]
    ClrnOfLn= row.iloc[0]["ClrnOfLn"]
    BlkdPs= row.iloc[0]["BlkdPs"]
    BlkCrs= row.iloc[0]["BlkCrs"]
    ShtBlk= row.iloc[0]["ShtBlk"]
    Recovery= row.iloc[0]["Recovery"]
    RcvryD3= row.iloc[0]["RcvryD3"]
    RcvryM3= row.iloc[0]["RcvryM3"]
    RcvryA3= row.iloc[0]["RcvryA3"]
    FoulCom= row.iloc[0]["FoulCom"]
    FlComD3= row.iloc[0]["FlComD3"]
    FlComM3= row.iloc[0]["FlComM3"]
    FlComA3= row.iloc[0]["FlComA3"]


    
    vector = ( GM,
Min,
Age,
MinIncET,
Touches,
TchsA3,
TouchOpBox,
TouchesWide,
RecDist,
PsRecD3,
PsRecM3,
PsRecA3,
PsRec,
PsAtt,
Pass,
PsDist,
ShrtPassAtt,
ShortPassCmp,
LongPassAtt,
LgPassCmp,
PsInOppHalf,
PsInFinal3rd,
PsCmpD3,
PsInA3rd,
PsInBox,
PsCmpInBox,
BackPass,
SquarePass,
PsSoP,
PsCmpSoP,
PassFwd,
FwdPsCmp,
Carries,
CarryDistAvg,
TakeOn,
TakeOn,
FoulSuf,
FlSufD3,
FlSufA3,
CrossOpen,
TimeTckl,
PsLostD3,
PsLostM3,
PsLostA3,
SeqEndsInShot,
SeqEndsInGoal,
Chance,
KeyPass,
Ast,
Shot,
SOG,
ShotInBox,
PossLost,
ShotHead,
xG,
Goal,
Duels,
DuelsD3,
DuelsM3,
DuelsA3,
Duel,
Duel_D3,
Duel_M3,
Duel_A3,
GrndDlWn,
GrndDlLs,
Aerials,
AerialWon,
AerialLoss,
Aerial,
Arl_DH,
Arl_AH,
Tckl,
TcklD3,
TcklM3,
TcklA3,
IntA3,
Int,
IntD3,
IntM3,
Clrnce,
ClrncD3,
ClrncM3,
ClrncA3,
HeadClear,
ClrnOfLn,
BlkdPs,
BlkCrs,
ShtBlk,
Recovery,
RcvryD3,
RcvryM3,
RcvryA3,
FoulCom,
FlComD3,
FlComM3,
FlComA3
)

    
    
    dic_2020[name] = vector
    
print ("Final number of players:", len(dic_2020))
# Out:
# Final number of players: 273

# %% [markdown]
# # COSINE DISTANCE

# %%
#Method that returns the squared sum's root of a given vector
def squared_sum (vector):
	suma_cuadrados = sum(x**2 for x in vector)
	return math.sqrt(suma_cuadrados)

#Method that returns the sum of the product (element by element) of two given vectors
def sum_product (vector1, vector2):
	return sum(vector1[i]*vector2[i] for i in range(len(vector1)))

#Method that returns an array containing tree tuples (similar_player_name, cosine_distance_value)
def cos_dista (asked_player):
	vector_player1 = list(dic_2020[asked_player])
	sqr_sum_player1 = squared_sum(vector_player1)
	similars = {}
	for player in dic_2020:
		if player!= asked_player:
			vector_player2 = list(dic_2020[player])
			sqr_sum_player2 = squared_sum(vector_player2)
			product = sum_product(vector_player1,vector_player2)
			cosine_distance = product/(sqr_sum_player1*sqr_sum_player2)
			if cosine_distance>0.8:
				similars[player]=cosine_distance
			else:
				pass
		else:
			pass
	similars_names = sorted(similars, key=similars.get, reverse=True)
	result = []
	cont = 0
	for similar in similars_names:
		if cont >9:
			break
		cosine_dist = similars[similar]
		result.append((similar,cosine_dist))
		cont +=1

	return result

similars_cd = cos_dista("Jose Artur de Lima Junior")
print ("======================COSINE DISTANCE========================")
print ("First: ", similars_cd[0][0], ". Cosine Distance: ",similars_cd[0][1])
print ("Second: ", similars_cd[1][0], ". Cosine Distance: ",similars_cd[1][1])
print ("Third: ", similars_cd[2][0], ". Cosine Distance: ",similars_cd[2][1])
print ("Fourth: ", similars_cd[3][0], ". Cosine Distance: ",similars_cd[3][1])
print ("Fifth: ", similars_cd[4][0], ". Cosine Distance: ",similars_cd[4][1])
print ("Sixth: ", similars_cd[5][0], ". Cosine Distance: ",similars_cd[5][1])
print ("Seventh: ", similars_cd[6][0], ". Cosine Distance: ",similars_cd[6][1])
print ("Eighth: ", similars_cd[7][0], ". Cosine Distance: ",similars_cd[7][1])
print ("Ninth: ", similars_cd[8][0], ". Cosine Distance: ",similars_cd[8][1])
print ("Tenth: ", similars_cd[9][0], ". Cosine Distance: ",similars_cd[9][1])
# Out:
# ======================COSINE DISTANCE========================
# First:  Aníbal Cesis Godoy . Cosine Distance:  0.9991467082070328
# Second:  Jackson William Yueill . Cosine Distance:  0.9985852577124043
# Third:  Darlington Joephillip Nagbe . Cosine Distance:  0.9985579338254721
# Fourth:  Bryan Josue Acosta Ramos . Cosine Distance:  0.9983359951883092
# Fifth:  Diego Ferney Chará Zamora . Cosine Distance:  0.9981953980290724
# Sixth:  Felipe Martins Campanholi . Cosine Distance:  0.9981770969868868
# Seventh:  Matheus Rossetto . Cosine Distance:  0.9981427591844366
# Eighth:  Dax McCarty . Cosine Distance:  0.9981100213180608
# Ninth:  Russell Canouse . Cosine Distance:  0.9981000258593448
# Tenth:  Pablo Enrique Ruíz . Cosine Distance:  0.9980856483966036

# %%
# Created a list of players

unique_players_names = players['playerFullName_x'].drop_duplicates().tolist()

unique_players_names
# Out:
# ['Cristian Roldan',
#  'Alexander Ring',
#  'Jose Artur de Lima Junior',
#  'Diego Ferney Chará Zamora',
#  'Marcelo Nicolás Lodeiro Benítez',
#  'Jackson William Yueill',
#  'Ján Greguš',
#  'Jordan Morris',
#  'Dax McCarty',
#  'Álvaro Medrán Just',
#  'Ocimar de Almeida Júnior',
#  'Victor Wanyama',
#  'Samuel Piette',
#  'Haris Medunjanin',
#  'Brenden Aaronson',
#  'Judson Silva Tavares',
#  'Keaton Alexander Parks',
#  'Pedro Miguel Martins Santos',
#  'Frankie Amaya',
#  'João Paulo Mior',
#  'Thiago dos Santos',
#  'Junior Leonardo Moreno Borrero',
#  'Eryk Williamson',
#  'Perry Kitchen',
#  'Matías Gabriel Vera',
#  'Diego Hernán Váleri',
#  'Ilie Sánchez Farrés',
#  'Jesús Manuel Medina Maldonado',
#  'Darlington Joephillip Nagbe',
#  'Aníbal Cesis Godoy',
#  'Gastón Claudio Giménez',
#  'Michael David Barrios Puerta',
#  'Marky Delgado',
#  'Eduard Andrés Atuesta Velasco',
#  'Darwin Adelso Cerén Delgado',
#  'Lewis Morgan',
#  'Victor Ulloa',
# ...

# %%
# Matched the 10 most similar players to each player in the list


cosine_2020 = []

for i in unique_players_names:
    result = cos_dista(i)
    cosine_2020.append(result)

# %%
cosine_2020[1]
# Out:
# [('Thomas Liam McNamara', 0.9986104864851898),
#  ('Keaton Alexander Parks', 0.9984290041973087),
#  ('Russell Canouse', 0.998316163079469),
#  ('Pablo Enrique Ruíz', 0.9982521471145592),
#  ('Ján Greguš', 0.9982295828325081),
#  ('Victor Wanyama', 0.9981922813956167),
#  ('Dax McCarty', 0.9981252138214228),
#  ('James Sands', 0.9980733366758165),
#  ('Felipe Martins Campanholi', 0.9980600764833818),
#  ('In-Beom Hwang', 0.9978910697783695)]

# %%
unique_players_names
# Out:
# ['Cristian Roldan',
#  'Alexander Ring',
#  'Jose Artur de Lima Junior',
#  'Diego Ferney Chará Zamora',
#  'Marcelo Nicolás Lodeiro Benítez',
#  'Jackson William Yueill',
#  'Ján Greguš',
#  'Jordan Morris',
#  'Dax McCarty',
#  'Álvaro Medrán Just',
#  'Ocimar de Almeida Júnior',
#  'Victor Wanyama',
#  'Samuel Piette',
#  'Haris Medunjanin',
#  'Brenden Aaronson',
#  'Judson Silva Tavares',
#  'Keaton Alexander Parks',
#  'Pedro Miguel Martins Santos',
#  'Frankie Amaya',
#  'João Paulo Mior',
#  'Thiago dos Santos',
#  'Junior Leonardo Moreno Borrero',
#  'Eryk Williamson',
#  'Perry Kitchen',
#  'Matías Gabriel Vera',
#  'Diego Hernán Váleri',
#  'Ilie Sánchez Farrés',
#  'Jesús Manuel Medina Maldonado',
#  'Darlington Joephillip Nagbe',
#  'Aníbal Cesis Godoy',
#  'Gastón Claudio Giménez',
#  'Michael David Barrios Puerta',
#  'Marky Delgado',
#  'Eduard Andrés Atuesta Velasco',
#  'Darwin Adelso Cerén Delgado',
#  'Lewis Morgan',
#  'Victor Ulloa',
# ...

# %%
names_2 = pd.DataFrame(unique_players_names)

# %%
names_2
# Out:
#                                              0
# 0                              Cristian Roldan
# 1                               Alexander Ring
# 2                    Jose Artur de Lima Junior
# 3                    Diego Ferney Chará Zamora
# 4              Marcelo Nicolás Lodeiro Benítez
# 5                       Jackson William Yueill
# 6                                   Ján Greguš
# 7                                Jordan Morris
# 8                                  Dax McCarty
# 9                           Álvaro Medrán Just
# 10                    Ocimar de Almeida Júnior
# 11                              Victor Wanyama
# 12                               Samuel Piette
# 13                            Haris Medunjanin
# 14                            Brenden Aaronson
# 15                        Judson Silva Tavares
# 16                      Keaton Alexander Parks
# 17                 Pedro Miguel Martins Santos
# 18                               Frankie Amaya
# ...

# %%
df = pd.DataFrame.from_records(cosine_2020)

# %%
df.insert(0, 'players_names', names_2)

# %%
df2 = df.copy()

# %%
# Exported list to excel

# %%
df2.to_csv('2020 matches.csv', encoding='utf-8-sig')

# %% [markdown]
# # 2019 Season

# %%
# Filtered by 2019 season

joined_2019 = joined[joined.Season == 'MLS 2019 (USA)']

# %%
# Dropped ID and categorical columns 

joined_2019.drop(['playerImageId_x', 'null_x', "Rank_y", "playerImageId_y", "null_y", 'Rank_x', 'playerId', 'Player_x', 'pos_x', 'teamImageId_x', 'teamName_x', 'teamShortName_x', 'teamAbbrevName_x', 'teamId_x','optaPersonId_x','leagueId_x','leagueName_x','Position_x','Team_x','seasonId_x','scatterId_x','scatterExtra_x' , 'Player_y', 'playerFullName_y', 'pos_y', 'teamImageId_y', 'teamName_y','teamShortName_y', 'teamAbbrevName_y', 'teamId_y', 'optaPersonId_y', 'firstName_y', 'lastName_y', 'optaTeamId_y', 'leagueId_y','Position_y', 'Team_y', 'GM_y', 'Min_y', 'Age_y', 'seasonId_y', 'scatterId_y', 'scatterExtra_y', 'Season', 'firstName_x', 'lastName_x', 'optaTeamId_x', 'leagueName_y'], axis=1, inplace=True)
# Out:
# C:\Users\cassi\anaconda3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# Reset index

joined_2019.reset_index(inplace=True)

# %% [markdown]
# #### Fixing players names

# %%
players = joined_2019[['playerFullName_x']]

# %%
names = []

for i in players['playerFullName_x']:
    results = ftfy.fix_text(i)
    names.append(results)

# %%
names = pd.DataFrame(names)
names.columns = ['playerFullName_x']

# %%
players = names.copy()

# %%
joined_2019.drop(['index', 'playerFullName_x'], axis=1, inplace=True)

# %%
joined_2019.head()
# Out:
#    GM_x  Min_x  Age_x  MinIncET  Touches  TchsA3  TouchOpBox  %TouchesWide  \
# 0    36   3270     36      3548     3229     692          12         0.647
# 1    35   3064     30      3279     2248     503          18         0.566
# 2    33   2928     25      3168     2336     586          55         0.666
# 3    34   2944     25      3146     2560     812          64         0.713
# 4    31   2790     29      3052     2516     296          53         0.490
#
#    RecDist  PsRecD3  PsRecM3  PsRecA3  PsRec  PsAtt  Pass%  PsDist  \
# 0     12.9      397     1315      300   2012   2708  0.845    19.6
# 1     12.7      207     1037      279   1523   1857  0.924    16.0
# 2     13.6      182      865      340   1387   1736  0.850    17.6
# 3     14.4      181     1042      552   1775   2068  0.852    15.1
# 4     13.2      421      948      166   1535   2047  0.835    19.1
#
#    ShrtPassAtt  %ShortPassCmp  LongPassAtt  %LgPassCmp  %PsInOppHalf  \
# ...

# %%
players
# Out:
#                            playerFullName_x
# 0                          Haris Medunjanin
# 1               Darlington Joephillip Nagbe
# 2                           Cristian Roldan
# 3                             Marky Delgado
# 4                            Alexander Ring
# 5                               Dax McCarty
# 6             Eduard Andrés Atuesta Velasco
# 7                                Ján Greguš
# 8                           Michael Bradley
# 9                 Diego Ferney Chará Zamora
# 10          Marcelo Nicolás Lodeiro Benítez
# 11              Jonathan dos Santos Ramírez
# 12         Felipe Alejandro Gutiérrez Leiva
# 13           Junior Leonardo Moreno Borrero
# 14                   Jackson William Yueill
# 15                           Latif Blessing
# 16                      Matías Gabriel Vera
# 17                          Magnus Eriksson
# 18              Óscar Boniek García Ramírez
# 19                               Sean Davis
# ...

# %%
joined_2019.insert(0,'playerFullName_x', players)

# %%
joined_2019
# Out:
#                            playerFullName_x  GM_x  Min_x  Age_x  MinIncET  \
# 0                          Haris Medunjanin    36   3270     36      3548
# 1               Darlington Joephillip Nagbe    35   3064     30      3279
# 2                           Cristian Roldan    33   2928     25      3168
# 3                             Marky Delgado    34   2944     25      3146
# 4                            Alexander Ring    31   2790     29      3052
# 5                               Dax McCarty    32   2850     33      3050
# 6             Eduard Andrés Atuesta Velasco    32   2816     23      3029
# 7                                Ján Greguš    31   2769     30      2974
# 8                           Michael Bradley    31   2762     33      2972
# 9                 Diego Ferney Chará Zamora    31   2696     34      2956
# 10          Marcelo Nicolás Lodeiro Benítez    30   2710     31      2940
# 11              Jonathan dos Santos Ramírez    31   2726     30      2922
# ...

# %%
# Creating a list of unique players for the season

unique_2019 =joined_2019.playerFullName_x.unique()

# %%
dic_2019 = {}

# %%
# Created vector with features to be used in cosine similarity

for name in unique_2019:
    row = joined_2019[joined_2019["playerFullName_x"]==name].iloc[[0]]
    name = row.iloc[0]["playerFullName_x"]
    GM = row.iloc[0]["GM_x"]
    Min = row.iloc[0]["Min_x"]
    Age = row.iloc[0]["Age_x"]
    MinIncET= row.iloc[0]["MinIncET"]
    Touches= row.iloc[0]["Touches"]
    TchsA3= row.iloc[0]["TchsA3"]
    TouchOpBox= row.iloc[0]["TouchOpBox"]
    TouchesWide= row.iloc[0]["%TouchesWide"]
    RecDist= row.iloc[0]["RecDist"]
    PsRecD3= row.iloc[0]["PsRecD3"]
    PsRecM3= row.iloc[0]["PsRecM3"]
    PsRecA3= row.iloc[0]["PsRecA3"]
    PsRec= row.iloc[0]["PsRec"]
    PsAtt= row.iloc[0]["PsAtt"]
    Pass= row.iloc[0]["Pass%"]
    PsDist= row.iloc[0]["PsDist"]
    ShrtPassAtt= row.iloc[0]["ShrtPassAtt"]
    ShortPassCmp= row.iloc[0]["%ShortPassCmp"]
    LongPassAtt= row.iloc[0]["LongPassAtt"]
    LgPassCmp= row.iloc[0]["%LgPassCmp"]
    PsInOppHalf= row.iloc[0]["%PsInOppHalf"]
    PsInFinal3rd= row.iloc[0]["%PsInFinal3rd"]
    PsCmpD3= row.iloc[0]["Ps%CmpD3"]
    PsInA3rd= row.iloc[0]["Ps%InA3rd"]
    PsInBox= row.iloc[0]["PsInBox"]
    PsCmpInBox= row.iloc[0]["PsCmpInBox"]
    BackPass= row.iloc[0]["BackPass"]
    SquarePass= row.iloc[0]["SquarePass"]
    PsSoP=row.iloc[0]["PsSoP"]
    PsCmpSoP= row.iloc[0]["PsCmpSoP"]
    PassFwd= row.iloc[0]["%PassFwd"]
    FwdPsCmp= row.iloc[0]["FwdPsCmp%"]
    Carries=row.iloc[0]["Carries"]
    CarryDistAvg= row.iloc[0]["CarryDistAvg"]
    TakeOn= row.iloc[0]["TakeOn"]
    TakeOn= row.iloc[0]["TakeOn%"]
    FoulSuf = row.iloc[0]["FoulSuf"]
    FlSufD3 = row.iloc[0]["FlSufD3"]
    FlSufA3 = row.iloc[0]["FlSufA3"]
    CrossOpen = row.iloc[0]["CrossOpen"]
    TimeTckl= row.iloc[0]["TimeTckl"]
    PsLostD3= row.iloc[0]["PsLostD3"]
    PsLostM3= row.iloc[0]["PsLostM3"]
    PsLostA3= row.iloc[0]["PsLostA3"]
    SeqEndsInShot= row.iloc[0]["SeqEndsInShot"]
    SeqEndsInGoal= row.iloc[0]["SeqEndsInGoal"]
    Chance= row.iloc[0]["Chance"]
    KeyPass= row.iloc[0]["KeyPass"]
    Ast= row.iloc[0]["Ast"]
    Shot= row.iloc[0]["Shot"]
    SOG= row.iloc[0]["SOG"]
    ShotInBox= row.iloc[0]["%ShotInBox"]
    PossLost= row.iloc[0]["PossLost"]
    ShotHead= row.iloc[0]["%ShotHead"]
    xG= row.iloc[0]["xG"]
    Goal= row.iloc[0]["Goal"]
    
    
    
    Duels= row.iloc[0]["Duels"]
    DuelsD3= row.iloc[0]["DuelsD3"]
    DuelsM3= row.iloc[0]["DuelsM3"]
    DuelsA3= row.iloc[0]["DuelsA3"]
    Duel= row.iloc[0]["Duel%"]
    Duel_D3= row.iloc[0]["Duel%D3"]
    Duel_M3= row.iloc[0]["Duel%M3"]
    Duel_A3= row.iloc[0]["Duel%A3"]
    GrndDlWn= row.iloc[0]["GrndDlWn"]
    GrndDlLs= row.iloc[0]["GrndDlLs"]
    Aerials=row.iloc[0]["Aerials"]
    AerialWon= row.iloc[0]["AerialWon"]
    AerialLoss= row.iloc[0]["AerialLoss"]
    Aerial= row.iloc[0]["Aerial%"]
    Arl_DH=row.iloc[0]["Arl%DH"]
    Arl_AH= row.iloc[0]["Arl%AH"]
    Tckl= row.iloc[0]["Tckl"]
    TcklD3= row.iloc[0]["TcklD3"]
    TcklM3 = row.iloc[0]["TcklM3"]
    TcklA3 = row.iloc[0]["TcklA3"]
    IntA3 = row.iloc[0]["IntA3"]
    Int = row.iloc[0]["Int"]
    IntD3= row.iloc[0]["IntD3"]
    IntM3= row.iloc[0]["IntM3"]
    Clrnce= row.iloc[0]["Clrnce"]
    ClrncD3= row.iloc[0]["ClrncD3"]
    ClrncM3= row.iloc[0]["ClrncM3"]
    ClrncA3= row.iloc[0]["ClrncA3"]
    HeadClear= row.iloc[0]["HeadClear"]
    ClrnOfLn= row.iloc[0]["ClrnOfLn"]
    BlkdPs= row.iloc[0]["BlkdPs"]
    BlkCrs= row.iloc[0]["BlkCrs"]
    ShtBlk= row.iloc[0]["ShtBlk"]
    Recovery= row.iloc[0]["Recovery"]
    RcvryD3= row.iloc[0]["RcvryD3"]
    RcvryM3= row.iloc[0]["RcvryM3"]
    RcvryA3= row.iloc[0]["RcvryA3"]
    FoulCom= row.iloc[0]["FoulCom"]
    FlComD3= row.iloc[0]["FlComD3"]
    FlComM3= row.iloc[0]["FlComM3"]
    FlComA3= row.iloc[0]["FlComA3"]


    
    vector = ( GM,
Min,
Age,
MinIncET,
Touches,
TchsA3,
TouchOpBox,
TouchesWide,
RecDist,
PsRecD3,
PsRecM3,
PsRecA3,
PsRec,
PsAtt,
Pass,
PsDist,
ShrtPassAtt,
ShortPassCmp,
LongPassAtt,
LgPassCmp,
PsInOppHalf,
PsInFinal3rd,
PsCmpD3,
PsInA3rd,
PsInBox,
PsCmpInBox,
BackPass,
SquarePass,
PsSoP,
PsCmpSoP,
PassFwd,
FwdPsCmp,
Carries,
CarryDistAvg,
TakeOn,
TakeOn,
FoulSuf,
FlSufD3,
FlSufA3,
CrossOpen,
TimeTckl,
PsLostD3,
PsLostM3,
PsLostA3,
SeqEndsInShot,
SeqEndsInGoal,
Chance,
KeyPass,
Ast,
Shot,
SOG,
ShotInBox,
PossLost,
ShotHead,
xG,
Goal,
Duels,
DuelsD3,
DuelsM3,
DuelsA3,
Duel,
Duel_D3,
Duel_M3,
Duel_A3,
GrndDlWn,
GrndDlLs,
Aerials,
AerialWon,
AerialLoss,
Aerial,
Arl_DH,
Arl_AH,
Tckl,
TcklD3,
TcklM3,
TcklA3,
IntA3,
Int,
IntD3,
IntM3,
Clrnce,
ClrncD3,
ClrncM3,
ClrncA3,
HeadClear,
ClrnOfLn,
BlkdPs,
BlkCrs,
ShtBlk,
Recovery,
RcvryD3,
RcvryM3,
RcvryA3,
FoulCom,
FlComD3,
FlComM3,
FlComA3
)

    
    
    dic_2019[name] = vector
    
print ("Final number of players:", len(dic_2019))
# Out:
# Final number of players: 263

# %% [markdown]
# # COSINE DISTANCE

# %%
#Method that returns the squared sum's root of a given vector
def squared_sum (vector):
	suma_cuadrados = sum(x**2 for x in vector)
	return math.sqrt(suma_cuadrados)

#Method that returns the sum of the product (element by element) of two given vectors
def sum_product (vector1, vector2):
	return sum(vector1[i]*vector2[i] for i in range(len(vector1)))

#Method that returns an array containing tree tuples (similar_player_name, cosine_distance_value)
def cos_dista (asked_player):
	vector_player1 = list(dic_2019[asked_player])
	sqr_sum_player1 = squared_sum(vector_player1)
	similars = {}
	for player in dic_2019:
		if player!= asked_player:
			vector_player2 = list(dic_2019[player])
			sqr_sum_player2 = squared_sum(vector_player2)
			product = sum_product(vector_player1,vector_player2)
			cosine_distance = product/(sqr_sum_player1*sqr_sum_player2)
			if cosine_distance>0.8:
				similars[player]=cosine_distance
			else:
				pass
		else:
			pass
	similars_names = sorted(similars, key=similars.get, reverse=True)
	result = []
	cont = 0
	for similar in similars_names:
		if cont >9:
			break
		cosine_dist = similars[similar]
		result.append((similar,cosine_dist))
		cont +=1

	return result

similars_cd = cos_dista("Jose Artur de Lima Junior")
print ("======================COSINE DISTANCE========================")
print ("First: ", similars_cd[0][0], ". Cosine Distance: ",similars_cd[0][1])
print ("Second: ", similars_cd[1][0], ". Cosine Distance: ",similars_cd[1][1])
print ("Third: ", similars_cd[2][0], ". Cosine Distance: ",similars_cd[2][1])
print ("Fourth: ", similars_cd[3][0], ". Cosine Distance: ",similars_cd[3][1])
print ("Fifth: ", similars_cd[4][0], ". Cosine Distance: ",similars_cd[4][1])
print ("Sixth: ", similars_cd[5][0], ". Cosine Distance: ",similars_cd[5][1])
print ("Seventh: ", similars_cd[6][0], ". Cosine Distance: ",similars_cd[6][1])
print ("Eighth: ", similars_cd[7][0], ". Cosine Distance: ",similars_cd[7][1])
print ("Ninth: ", similars_cd[8][0], ". Cosine Distance: ",similars_cd[8][1])
print ("Tenth: ", similars_cd[9][0], ". Cosine Distance: ",similars_cd[9][1])
# Out:
# ======================COSINE DISTANCE========================
# First:  Eric Daian Remedi . Cosine Distance:  0.9991977528946026
# Second:  Kyle Beckerman . Cosine Distance:  0.9991820055369721
# Third:  Aníbal Cesis Godoy . Cosine Distance:  0.9988664948613977
# Fourth:  Dax McCarty . Cosine Distance:  0.9986507985587423
# Fifth:  In-Beom Hwang . Cosine Distance:  0.9986172718525708
# Sixth:  Oriol Rosell Argerich . Cosine Distance:  0.9985636408258444
# Seventh:  Felipe Martins Campanholi . Cosine Distance:  0.9984148631704391
# Eighth:  Ilie Sánchez Farrés . Cosine Distance:  0.9983914878348744
# Ninth:  Osvaldo Alonso Moreno . Cosine Distance:  0.9982934591189163
# Tenth:  Renzo José Zambrano . Cosine Distance:  0.9981342290526108

# %%
# Created a list of players

unique_players_names = players['playerFullName_x'].drop_duplicates().tolist()

unique_players_names
# Out:
# ['Haris Medunjanin',
#  'Darlington Joephillip Nagbe',
#  'Cristian Roldan',
#  'Marky Delgado',
#  'Alexander Ring',
#  'Dax McCarty',
#  'Eduard Andrés Atuesta Velasco',
#  'Ján Greguš',
#  'Michael Bradley',
#  'Diego Ferney Chará Zamora',
#  'Marcelo Nicolás Lodeiro Benítez',
#  'Jonathan dos Santos Ramírez',
#  'Felipe Alejandro Gutiérrez Leiva',
#  'Junior Leonardo Moreno Borrero',
#  'Jackson William Yueill',
#  'Latif Blessing',
#  'Matías Gabriel Vera',
#  'Magnus Eriksson',
#  'Óscar Boniek García Ramírez',
#  'Sean Davis',
#  'In-Beom Hwang',
#  'Mark Anthony Kaye',
#  'Jose Artur de Lima Junior',
#  'Marc Rzatkowski',
#  'Osvaldo Alonso Moreno',
#  'Pedro Miguel Martins Santos',
#  'Sebastian Lletget',
#  'Albert Rusnák',
#  'Wil Trapp',
#  'Ilie Sánchez Farrés',
#  'Everton Luiz Guimaraes Bilher',
#  'Joe Benny Corona Crespín',
#  'Kyle Beckerman',
#  'Bryan Josue Acosta Ramos',
#  'Samuel Piette',
#  'Jack Alexander Price',
#  'Jefferson David Savarino Quintero',
# ...

# %%
# Matched the 10 most similar players to each player in the list


cosine_2019 = []

for i in unique_players_names:
    result = cos_dista(i)
    cosine_2019.append(result)

# %%
cosine_2019[1]
# Out:
# [('In-Beom Hwang', 0.998561296279529),
#  ('Daniel Leyva', 0.9978118493420415),
#  ('Jose Artur de Lima Junior', 0.9977564967429233),
#  ('Eric Daian Remedi', 0.997536870464077),
#  ('Felipe Martins Campanholi', 0.9974511084566138),
#  ('Tony Rocha', 0.9974219498855112),
#  ('Junior Leonardo Moreno Borrero', 0.9973737898898336),
#  ('Brandon Servania', 0.9972753798828027),
#  ('Kyle Beckerman', 0.9971183665833622),
#  ('Jacori Hayes', 0.9970049547224522)]

# %%
unique_players_names
# Out:
# ['Haris Medunjanin',
#  'Darlington Joephillip Nagbe',
#  'Cristian Roldan',
#  'Marky Delgado',
#  'Alexander Ring',
#  'Dax McCarty',
#  'Eduard Andrés Atuesta Velasco',
#  'Ján Greguš',
#  'Michael Bradley',
#  'Diego Ferney Chará Zamora',
#  'Marcelo Nicolás Lodeiro Benítez',
#  'Jonathan dos Santos Ramírez',
#  'Felipe Alejandro Gutiérrez Leiva',
#  'Junior Leonardo Moreno Borrero',
#  'Jackson William Yueill',
#  'Latif Blessing',
#  'Matías Gabriel Vera',
#  'Magnus Eriksson',
#  'Óscar Boniek García Ramírez',
#  'Sean Davis',
#  'In-Beom Hwang',
#  'Mark Anthony Kaye',
#  'Jose Artur de Lima Junior',
#  'Marc Rzatkowski',
#  'Osvaldo Alonso Moreno',
#  'Pedro Miguel Martins Santos',
#  'Sebastian Lletget',
#  'Albert Rusnák',
#  'Wil Trapp',
#  'Ilie Sánchez Farrés',
#  'Everton Luiz Guimaraes Bilher',
#  'Joe Benny Corona Crespín',
#  'Kyle Beckerman',
#  'Bryan Josue Acosta Ramos',
#  'Samuel Piette',
#  'Jack Alexander Price',
#  'Jefferson David Savarino Quintero',
# ...

# %%
names_2 = pd.DataFrame(unique_players_names)

# %%
names_2
# Out:
#                                           0
# 0                          Haris Medunjanin
# 1               Darlington Joephillip Nagbe
# 2                           Cristian Roldan
# 3                             Marky Delgado
# 4                            Alexander Ring
# 5                               Dax McCarty
# 6             Eduard Andrés Atuesta Velasco
# 7                                Ján Greguš
# 8                           Michael Bradley
# 9                 Diego Ferney Chará Zamora
# 10          Marcelo Nicolás Lodeiro Benítez
# 11              Jonathan dos Santos Ramírez
# 12         Felipe Alejandro Gutiérrez Leiva
# 13           Junior Leonardo Moreno Borrero
# 14                   Jackson William Yueill
# 15                           Latif Blessing
# 16                      Matías Gabriel Vera
# 17                          Magnus Eriksson
# 18              Óscar Boniek García Ramírez
# 19                               Sean Davis
# ...

# %%
df = pd.DataFrame.from_records(cosine_2019)

# %%
df.insert(0, 'players_names', names_2)

# %%
df2 = df.copy()

# %%
# Exported list to excel

# %%
df2.to_csv('2019 matches.csv', encoding='utf-8-sig')

# %% [markdown]
# # 2018 Season

# %%
# Filtered by 2018 season

joined_2018 = joined[joined.Season == 'MLS 2018 (USA)']

# %%
# Dropped ID and categorical columns 

joined_2018.drop(['playerImageId_x', 'null_x', "Rank_y", "playerImageId_y", "null_y", 'Rank_x', 'playerId', 'Player_x', 'pos_x', 'teamImageId_x', 'teamName_x', 'teamShortName_x', 'teamAbbrevName_x', 'teamId_x','optaPersonId_x','leagueId_x','leagueName_x','Position_x','Team_x','seasonId_x','scatterId_x','scatterExtra_x' , 'Player_y', 'playerFullName_y', 'pos_y', 'teamImageId_y', 'teamName_y','teamShortName_y', 'teamAbbrevName_y', 'teamId_y', 'optaPersonId_y', 'firstName_y', 'lastName_y', 'optaTeamId_y', 'leagueId_y','Position_y', 'Team_y', 'GM_y', 'Min_y', 'Age_y', 'seasonId_y', 'scatterId_y', 'scatterExtra_y', 'Season', 'firstName_x', 'lastName_x', 'optaTeamId_x', 'leagueName_y'], axis=1, inplace=True)
# Out:
# C:\Users\cassi\anaconda3\lib\site-packages\pandas\core\frame.py:4305: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# Reset index

joined_2018.reset_index(inplace=True)

# %% [markdown]
# #### Fixing players names

# %%
players = joined_2018[['playerFullName_x']]

# %%
names = []

for i in players['playerFullName_x']:
    results = ftfy.fix_text(i)
    names.append(results)

# %%
names = pd.DataFrame(names)
names.columns = ['playerFullName_x']

# %%
players = names.copy()

# %%
joined_2018.drop(['index', 'playerFullName_x'], axis=1, inplace=True)

# %%
joined_2018.head()
# Out:
#    GM_x  Min_x  Age_x  MinIncET  Touches  TchsA3  TouchOpBox  %TouchesWide  \
# 0    38   3420     30      3713     3059     512          40         0.450
# 1    36   3185     34      3427     2283     719          66         0.655
# 2    35   3084     24      3288     2522     384          42         0.618
# 3    34   3000     26      3199     2202     197           3         0.569
# 4    34   2998     34      3186     2892    1031         137         0.681
#
#    RecDist  PsRecD3  PsRecM3  PsRecA3  PsRec  PsAtt  Pass%  PsDist  \
# 0     13.5      397     1281      284   1962   2633  0.848    18.8
# 1     14.7      123      910      418   1451   1759  0.820    19.1
# 2     13.0      344     1104      208   1656   2042  0.856    17.8
# 3     12.8      278      893       96   1267   1812  0.875    18.2
# 4     13.4      136     1232      550   1918   2096  0.804    18.1
#
#    ShrtPassAtt  %ShortPassCmp  LongPassAtt  %LgPassCmp  %PsInOppHalf  \
# ...

# %%
players
# Out:
#                             playerFullName_x
# 0                        Ilie Sánchez Farrés
# 1                     Róger Espinoza Ramírez
# 2                  Jose Artur de Lima Junior
# 3                              Samuel Piette
# 4                  Maximiliano Nicol Moralez
# 5                                  Wil Trapp
# 6                             Kyle Beckerman
# 7                   Sebastián Marcelo Blanco
# 8                            Cristian Roldan
# 9                                 Sean Davis
# 10                           Benny Feilhaber
# 11                          Alejandro Bedoya
# 12                 Diego Ferney Chará Zamora
# 13                      Jack Alexander Price
# 14                       Saphir Sliti Taïder
# 15                  Alejandro Romero Gamarra
# 16                   Luciano Federico Acosta
# 17            Carlos Armando Gruezo Arboleda
# 18                               Tyler Adams
# 19                 Federico Fernando Higuaín
# ...

# %%
joined_2018.insert(0,'playerFullName_x', players)

# %%
joined_2018
# Out:
#                             playerFullName_x  GM_x  Min_x  Age_x  MinIncET  \
# 0                        Ilie Sánchez Farrés    38   3420     30      3713
# 1                     Róger Espinoza Ramírez    36   3185     34      3427
# 2                  Jose Artur de Lima Junior    35   3084     24      3288
# 3                              Samuel Piette    34   3000     26      3199
# 4                  Maximiliano Nicol Moralez    34   2998     34      3186
# 5                                  Wil Trapp    33   2920     28      3132
# 6                             Kyle Beckerman    34   2891     38      3123
# 7                   Sebastián Marcelo Blanco    34   2891     32      3120
# 8                            Cristian Roldan    33   2904     25      3119
# 9                                 Sean Davis    36   2901     28      3078
# 10                           Benny Feilhaber    34   2850     36      3044
# ...

# %%
# Creating a list of unique players for the season

unique_2018 =joined_2018.playerFullName_x.unique()

# %%
dic_2018 = {}

# %%
# Created vector with features to be used in cosine similarity

for name in unique_2018:
    row = joined_2018[joined_2018["playerFullName_x"]==name].iloc[[0]]
    name = row.iloc[0]["playerFullName_x"]
    GM = row.iloc[0]["GM_x"]
    Min = row.iloc[0]["Min_x"]
    Age = row.iloc[0]["Age_x"]
    MinIncET= row.iloc[0]["MinIncET"]
    Touches= row.iloc[0]["Touches"]
    TchsA3= row.iloc[0]["TchsA3"]
    TouchOpBox= row.iloc[0]["TouchOpBox"]
    TouchesWide= row.iloc[0]["%TouchesWide"]
    RecDist= row.iloc[0]["RecDist"]
    PsRecD3= row.iloc[0]["PsRecD3"]
    PsRecM3= row.iloc[0]["PsRecM3"]
    PsRecA3= row.iloc[0]["PsRecA3"]
    PsRec= row.iloc[0]["PsRec"]
    PsAtt= row.iloc[0]["PsAtt"]
    Pass= row.iloc[0]["Pass%"]
    PsDist= row.iloc[0]["PsDist"]
    ShrtPassAtt= row.iloc[0]["ShrtPassAtt"]
    ShortPassCmp= row.iloc[0]["%ShortPassCmp"]
    LongPassAtt= row.iloc[0]["LongPassAtt"]
    LgPassCmp= row.iloc[0]["%LgPassCmp"]
    PsInOppHalf= row.iloc[0]["%PsInOppHalf"]
    PsInFinal3rd= row.iloc[0]["%PsInFinal3rd"]
    PsCmpD3= row.iloc[0]["Ps%CmpD3"]
    PsInA3rd= row.iloc[0]["Ps%InA3rd"]
    PsInBox= row.iloc[0]["PsInBox"]
    PsCmpInBox= row.iloc[0]["PsCmpInBox"]
    BackPass= row.iloc[0]["BackPass"]
    SquarePass= row.iloc[0]["SquarePass"]
    PsSoP=row.iloc[0]["PsSoP"]
    PsCmpSoP= row.iloc[0]["PsCmpSoP"]
    PassFwd= row.iloc[0]["%PassFwd"]
    FwdPsCmp= row.iloc[0]["FwdPsCmp%"]
    Carries=row.iloc[0]["Carries"]
    CarryDistAvg= row.iloc[0]["CarryDistAvg"]
    TakeOn= row.iloc[0]["TakeOn"]
    TakeOn= row.iloc[0]["TakeOn%"]
    FoulSuf = row.iloc[0]["FoulSuf"]
    FlSufD3 = row.iloc[0]["FlSufD3"]
    FlSufA3 = row.iloc[0]["FlSufA3"]
    CrossOpen = row.iloc[0]["CrossOpen"]
    TimeTckl= row.iloc[0]["TimeTckl"]
    PsLostD3= row.iloc[0]["PsLostD3"]
    PsLostM3= row.iloc[0]["PsLostM3"]
    PsLostA3= row.iloc[0]["PsLostA3"]
    SeqEndsInShot= row.iloc[0]["SeqEndsInShot"]
    SeqEndsInGoal= row.iloc[0]["SeqEndsInGoal"]
    Chance= row.iloc[0]["Chance"]
    KeyPass= row.iloc[0]["KeyPass"]
    Ast= row.iloc[0]["Ast"]
    Shot= row.iloc[0]["Shot"]
    SOG= row.iloc[0]["SOG"]
    ShotInBox= row.iloc[0]["%ShotInBox"]
    PossLost= row.iloc[0]["PossLost"]
    ShotHead= row.iloc[0]["%ShotHead"]
    xG= row.iloc[0]["xG"]
    Goal= row.iloc[0]["Goal"]
    
    
    
    Duels= row.iloc[0]["Duels"]
    DuelsD3= row.iloc[0]["DuelsD3"]
    DuelsM3= row.iloc[0]["DuelsM3"]
    DuelsA3= row.iloc[0]["DuelsA3"]
    Duel= row.iloc[0]["Duel%"]
    Duel_D3= row.iloc[0]["Duel%D3"]
    Duel_M3= row.iloc[0]["Duel%M3"]
    Duel_A3= row.iloc[0]["Duel%A3"]
    GrndDlWn= row.iloc[0]["GrndDlWn"]
    GrndDlLs= row.iloc[0]["GrndDlLs"]
    Aerials=row.iloc[0]["Aerials"]
    AerialWon= row.iloc[0]["AerialWon"]
    AerialLoss= row.iloc[0]["AerialLoss"]
    Aerial= row.iloc[0]["Aerial%"]
    Arl_DH=row.iloc[0]["Arl%DH"]
    Arl_AH= row.iloc[0]["Arl%AH"]
    Tckl= row.iloc[0]["Tckl"]
    TcklD3= row.iloc[0]["TcklD3"]
    TcklM3 = row.iloc[0]["TcklM3"]
    TcklA3 = row.iloc[0]["TcklA3"]
    IntA3 = row.iloc[0]["IntA3"]
    Int = row.iloc[0]["Int"]
    IntD3= row.iloc[0]["IntD3"]
    IntM3= row.iloc[0]["IntM3"]
    Clrnce= row.iloc[0]["Clrnce"]
    ClrncD3= row.iloc[0]["ClrncD3"]
    ClrncM3= row.iloc[0]["ClrncM3"]
    ClrncA3= row.iloc[0]["ClrncA3"]
    HeadClear= row.iloc[0]["HeadClear"]
    ClrnOfLn= row.iloc[0]["ClrnOfLn"]
    BlkdPs= row.iloc[0]["BlkdPs"]
    BlkCrs= row.iloc[0]["BlkCrs"]
    ShtBlk= row.iloc[0]["ShtBlk"]
    Recovery= row.iloc[0]["Recovery"]
    RcvryD3= row.iloc[0]["RcvryD3"]
    RcvryM3= row.iloc[0]["RcvryM3"]
    RcvryA3= row.iloc[0]["RcvryA3"]
    FoulCom= row.iloc[0]["FoulCom"]
    FlComD3= row.iloc[0]["FlComD3"]
    FlComM3= row.iloc[0]["FlComM3"]
    FlComA3= row.iloc[0]["FlComA3"]


    
    vector = ( GM,
Min,
Age,
MinIncET,
Touches,
TchsA3,
TouchOpBox,
TouchesWide,
RecDist,
PsRecD3,
PsRecM3,
PsRecA3,
PsRec,
PsAtt,
Pass,
PsDist,
ShrtPassAtt,
ShortPassCmp,
LongPassAtt,
LgPassCmp,
PsInOppHalf,
PsInFinal3rd,
PsCmpD3,
PsInA3rd,
PsInBox,
PsCmpInBox,
BackPass,
SquarePass,
PsSoP,
PsCmpSoP,
PassFwd,
FwdPsCmp,
Carries,
CarryDistAvg,
TakeOn,
TakeOn,
FoulSuf,
FlSufD3,
FlSufA3,
CrossOpen,
TimeTckl,
PsLostD3,
PsLostM3,
PsLostA3,
SeqEndsInShot,
SeqEndsInGoal,
Chance,
KeyPass,
Ast,
Shot,
SOG,
ShotInBox,
PossLost,
ShotHead,
xG,
Goal,
Duels,
DuelsD3,
DuelsM3,
DuelsA3,
Duel,
Duel_D3,
Duel_M3,
Duel_A3,
GrndDlWn,
GrndDlLs,
Aerials,
AerialWon,
AerialLoss,
Aerial,
Arl_DH,
Arl_AH,
Tckl,
TcklD3,
TcklM3,
TcklA3,
IntA3,
Int,
IntD3,
IntM3,
Clrnce,
ClrncD3,
ClrncM3,
ClrncA3,
HeadClear,
ClrnOfLn,
BlkdPs,
BlkCrs,
ShtBlk,
Recovery,
RcvryD3,
RcvryM3,
RcvryA3,
FoulCom,
FlComD3,
FlComM3,
FlComA3
)

    
    
    dic_2018[name] = vector
    
print ("Final number of players:", len(dic_2018))
# Out:
# Final number of players: 245

# %% [markdown]
# # COSINE DISTANCE

# %%
#Method that returns the squared sum's root of a given vector
def squared_sum (vector):
	suma_cuadrados = sum(x**2 for x in vector)
	return math.sqrt(suma_cuadrados)

#Method that returns the sum of the product (element by element) of two given vectors
def sum_product (vector1, vector2):
	return sum(vector1[i]*vector2[i] for i in range(len(vector1)))

#Method that returns an array containing tree tuples (similar_player_name, cosine_distance_value)
def cos_dista (asked_player):
	vector_player1 = list(dic_2018[asked_player])
	sqr_sum_player1 = squared_sum(vector_player1)
	similars = {}
	for player in dic_2018:
		if player!= asked_player:
			vector_player2 = list(dic_2018[player])
			sqr_sum_player2 = squared_sum(vector_player2)
			product = sum_product(vector_player1,vector_player2)
			cosine_distance = product/(sqr_sum_player1*sqr_sum_player2)
			if cosine_distance>0.8:
				similars[player]=cosine_distance
			else:
				pass
		else:
			pass
	similars_names = sorted(similars, key=similars.get, reverse=True)
	result = []
	cont = 0
	for similar in similars_names:
		if cont >9:
			break
		cosine_dist = similars[similar]
		result.append((similar,cosine_dist))
		cont +=1

	return result

similars_cd = cos_dista("Jose Artur de Lima Junior")
print ("======================COSINE DISTANCE========================")
print ("First: ", similars_cd[0][0], ". Cosine Distance: ",similars_cd[0][1])
print ("Second: ", similars_cd[1][0], ". Cosine Distance: ",similars_cd[1][1])
print ("Third: ", similars_cd[2][0], ". Cosine Distance: ",similars_cd[2][1])
print ("Fourth: ", similars_cd[3][0], ". Cosine Distance: ",similars_cd[3][1])
print ("Fifth: ", similars_cd[4][0], ". Cosine Distance: ",similars_cd[4][1])
print ("Sixth: ", similars_cd[5][0], ". Cosine Distance: ",similars_cd[5][1])
print ("Seventh: ", similars_cd[6][0], ". Cosine Distance: ",similars_cd[6][1])
print ("Eighth: ", similars_cd[7][0], ". Cosine Distance: ",similars_cd[7][1])
print ("Ninth: ", similars_cd[8][0], ". Cosine Distance: ",similars_cd[8][1])
print ("Tenth: ", similars_cd[9][0], ". Cosine Distance: ",similars_cd[9][1])
# Out:
# ======================COSINE DISTANCE========================
# First:  Kyle Beckerman . Cosine Distance:  0.9990834631868613
# Second:  Stephen Obayan Sunday . Cosine Distance:  0.9990303498494938
# Third:  Dax McCarty . Cosine Distance:  0.9984384830677958
# Fourth:  Ilie Sánchez Farrés . Cosine Distance:  0.9981719887154696
# Fifth:  Aníbal Cesis Godoy . Cosine Distance:  0.9981608586360035
# Sixth:  Jackson William Yueill . Cosine Distance:  0.9980622078203142
# Seventh:  Oriol Rosell Argerich . Cosine Distance:  0.9980041398033368
# Eighth:  Ebenezer Ofori . Cosine Distance:  0.9976905690513236
# Ninth:  Jack Alexander Price . Cosine Distance:  0.9976749391710896
# Tenth:  Eduard Andrés Atuesta Velasco . Cosine Distance:  0.9975697876816259

# %%
# Created a list of players

unique_players_names = players['playerFullName_x'].drop_duplicates().tolist()

unique_players_names
# Out:
# ['Ilie Sánchez Farrés',
#  'Róger Espinoza Ramírez',
#  'Jose Artur de Lima Junior',
#  'Samuel Piette',
#  'Maximiliano Nicol Moralez',
#  'Wil Trapp',
#  'Kyle Beckerman',
#  'Sebastián Marcelo Blanco',
#  'Cristian Roldan',
#  'Sean Davis',
#  'Benny Feilhaber',
#  'Alejandro Bedoya',
#  'Diego Ferney Chará Zamora',
#  'Jack Alexander Price',
#  'Saphir Sliti Taïder',
#  'Alejandro Romero Gamarra',
#  'Luciano Federico Acosta',
#  'Carlos Armando Gruezo Arboleda',
#  'Tyler Adams',
#  'Federico Fernando Higuaín',
#  'Haris Medunjanin',
#  'Rasmus Schüller',
#  'Marcelo Nicolás Lodeiro Benítez',
#  'Miguel Ángel Almirón Rejala',
#  'Diego Hernán Váleri',
#  'Albert Rusnák',
#  'Borek Dockal',
#  'Damir Kreilach',
#  'Darlington Joephillip Nagbe',
#  'Pedro Miguel Martins Santos',
#  'Alexander Ring',
#  'Perry Kitchen',
#  'Aníbal Cesis Godoy',
#  'Tomás Martínez',
#  'Luís Alberto Caicedo Mosquera',
#  'Jeff Larentowicz',
#  'Victor Ulloa',
#  'Dax McCarty',
# ...

# %%
# Matched the 10 most similar players to each player in the list


cosine_2018 = []

for i in unique_players_names:
    result = cos_dista(i)
    cosine_2018.append(result)

# %%
cosine_2018[1]
# Out:
# [('Cristian Roldan', 0.9984235480539316),
#  ('Óscar Boniek García Ramírez', 0.9978097028569523),
#  ('Felipe Alejandro Gutiérrez Leiva', 0.997353115746411),
#  ('Tony Tchani', 0.9972242429271985),
#  ('Tomás Martínez', 0.9971362036710997),
#  ('Felipe Martins Campanholi', 0.9970283189723478),
#  ('Damir Kreilach', 0.9968519813472714),
#  ('Alejandro Bedoya', 0.9966279845145279),
#  ('Yamil Rodrigo Asad', 0.9965351753029091),
#  ('Servando Carrasco', 0.9963426675697858)]

# %%
unique_players_names
# Out:
# ['Ilie Sánchez Farrés',
#  'Róger Espinoza Ramírez',
#  'Jose Artur de Lima Junior',
#  'Samuel Piette',
#  'Maximiliano Nicol Moralez',
#  'Wil Trapp',
#  'Kyle Beckerman',
#  'Sebastián Marcelo Blanco',
#  'Cristian Roldan',
#  'Sean Davis',
#  'Benny Feilhaber',
#  'Alejandro Bedoya',
#  'Diego Ferney Chará Zamora',
#  'Jack Alexander Price',
#  'Saphir Sliti Taïder',
#  'Alejandro Romero Gamarra',
#  'Luciano Federico Acosta',
#  'Carlos Armando Gruezo Arboleda',
#  'Tyler Adams',
#  'Federico Fernando Higuaín',
#  'Haris Medunjanin',
#  'Rasmus Schüller',
#  'Marcelo Nicolás Lodeiro Benítez',
#  'Miguel Ángel Almirón Rejala',
#  'Diego Hernán Váleri',
#  'Albert Rusnák',
#  'Borek Dockal',
#  'Damir Kreilach',
#  'Darlington Joephillip Nagbe',
#  'Pedro Miguel Martins Santos',
#  'Alexander Ring',
#  'Perry Kitchen',
#  'Aníbal Cesis Godoy',
#  'Tomás Martínez',
#  'Luís Alberto Caicedo Mosquera',
#  'Jeff Larentowicz',
#  'Victor Ulloa',
#  'Dax McCarty',
# ...

# %%
names_2 = pd.DataFrame(unique_players_names)

# %%
names_2
# Out:
#                                            0
# 0                        Ilie Sánchez Farrés
# 1                     Róger Espinoza Ramírez
# 2                  Jose Artur de Lima Junior
# 3                              Samuel Piette
# 4                  Maximiliano Nicol Moralez
# 5                                  Wil Trapp
# 6                             Kyle Beckerman
# 7                   Sebastián Marcelo Blanco
# 8                            Cristian Roldan
# 9                                 Sean Davis
# 10                           Benny Feilhaber
# 11                          Alejandro Bedoya
# 12                 Diego Ferney Chará Zamora
# 13                      Jack Alexander Price
# 14                       Saphir Sliti Taïder
# 15                  Alejandro Romero Gamarra
# 16                   Luciano Federico Acosta
# 17            Carlos Armando Gruezo Arboleda
# 18                               Tyler Adams
# 19                 Federico Fernando Higuaín
# ...

# %%
df = pd.DataFrame.from_records(cosine_2018)

# %%
df.insert(0, 'players_names', names_2)

# %%
df2 = df.copy()

# %%
# Exported list to excel

# %%
df2.to_csv('2018 matches.csv', encoding='utf-8-sig')

# %%
joined
# Out:
#      Rank_x                   playerId  playerImageId_x        Player_x  \
# 0         1  bdwbbro06256s61ed42kejvmd         102680.0            Ilie
# 1         2  eds7hz8z52qf06c3oug7nivv9          49720.0   H. Medunjanin
# 2         3  16dmszlgoxqwzncidglrv9j9x         111681.0     R. Espinoza
# 3         4  35fvjkn05x6cr2kx3yiif1jop         235848.0           Artur
# 4         5  d38mrccgoud3qomh3supk202d         142574.0        D. Nagbe
# ..      ...                        ...              ...             ...
# 776     777   hhrqf0zpymjvqwoxitlwp04p         318721.0      T. ChacÃ³n
# 777     778  27hwtukeqxh91ch1f3qr1it49         537552.0  V. Castellanos
# 778     779  bzry98hy5bhb4mhil7j4ccfdh         248333.0        M. Azira
# 779     780  819j4bs174i6wn2a4ry79xj9x         235710.0     T. Thompson
# 780     781  eoiimmhy0bdg3guq88jihpyol         108178.0        J. Mason
#
#                                  playerFullName_x                       pos_x  \
# ...

# %%
players = joined[['playerFullName_x']]

# %%
names = []

for i in players['playerFullName_x']:
    results = ftfy.fix_text(i)
    names.append(results)

# %%
names = pd.DataFrame(names)
names.columns = ['playerFullName_x']

# %%
players = names.copy()

# %%
joined.drop(['playerFullName_x'], axis=1, inplace=True)

# %%
joined.insert(0,'playerFullName_x', players)

# %%
joined.drop(['Rank_y', 'null_y'], axis=1, inplace=True)

# %%
joined.to_csv('joined.csv', encoding='utf-8-sig')
